# %%
import sys
import os

# 현재 test.ipynb는 miraeasset2025/TEST 안에 있으므로
# 한 단계 위로 가서 sys.path에 'MiraeAsset' 경로를 추가해야 패키지 인식 가능
sys.path.append(os.path.abspath("../.."))

from miraeasset2025.dart.dart_crawler import DartCrawler
# Out:
# /home/user/exercise_j/MiraeAsset/virtual/mirae/lib/python3.12/site-packages/pykrx/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
crawler = DartCrawler()

# %%
result = crawler.crawl_company_reports('006800', '2025')
# Out:
# 2025-07-25 12:15:12 - [INFO] 006800_2025년_1분기사업보고서 검색 완료
# 2025-07-25 12:15:12 - [INFO] 미래에셋증권_006800_2025_11013_1분기사업보고서_연결재무제표 저장 완료
# 2025-07-25 12:15:13 - [INFO] 미래에셋증권_006800_2025_11013_1분기사업보고서_연결재무제표주석 저장 완료
# 2025-07-25 12:15:13 - [ERROR] 보고서 처리 중 오류 발생 (반기사업보고서, 2025): '<' not supported between instances of 'str' and 'int'
# 2025-07-25 12:15:13 - [ERROR] 보고서 처리 중 오류 발생 (3분기사업보고서, 2025): '<' not supported between instances of 'str' and 'int'
# 2025-07-25 12:15:13 - [ERROR] 보고서 처리 중 오류 발생 (사업보고서, 2025): '<' not supported between instances of 'str' and 'int'
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}

# %%
result.keys()
# Out:
# dict_keys(['미래에셋증권_006800_2025_11013_1분기사업보고서_연결재무제표', '미래에셋증권_006800_2025_11013_1분기사업보고서_연결재무제표주석'])

# %%
result['미래에셋증권_006800_2025_11013_1분기사업보고서_연결재무제표'][1]
# Out:
#                   Unnamed: 0_level_0 제 57 기 1분기           제 56 기 1분기
#                   Unnamed: 0_level_1        3개월        누적        3개월        누적
# 0                          영업수익 (주6)    6052641   6052641    6278995   6278995
# 1                     수수료수익 (주30,43)     391219    391219     326116    326116
# 2       당기손익-공정가치측정금융상품관련이익 (주23,31)    3450433   3450433    3920324   3920324
# 3        기타포괄손익-공정가치측정금융상품관련이익 (주31)      28686     28686      11121     11121
# 4                       이자수익 (주6,32)    1418147   1418147    1315617   1315617
# 5                  상각후원가측정금융자산관련이자수익    1064396   1064396     998988    998988
# 6            기타포괄손익-공정가치측정금융자산관련이자수익     127079    127079     126907    126907
# 7              당기손익-공정가치측정금융자산관련이자수익     226672    226672     189722    189722
# 8                         신용손실충당금환입액       1352      1352       7489      7489
# 9                       외환거래이익 (주33)     518284    518284     468890    468890
# 10                  기타의영업수익 (주34,43)     244520    244520     229438    229438
# 11                         영업비용 (주6)    5706456   5706456    6008522   6008522
# 12                    수수료비용 (주30,43)     150813    150813      69301     69301
# 13      당기손익-공정가치측정금융상품관련손실 (주23,31)    3167308   3167308    3651816   3651816
# 14       기타포괄손익-공정가치측정금융상품관련손실 (주31)       1286      1286        648       648
# 15                      이자비용 (주6,32)    1315700   1315700    1213767   1213767
# 16                        신용손실충당금전입액      19392     19392      27277     27277
# 17                      외환거래손실 (주33)     517307    517307     563859    563859
# 18                      인건비 (주35,43)     259998    259998     239922    239922
# 19                    판매관리비 (주36,43)     206758    206758     167137    167137
# 20                  기타의영업비용 (주34,43)      67894     67894      74795     74795
# 21                          영업이익(손실)     346185    346185     270473    270473
# 22                        영업외손익 (주6)      (118)     (118)   (40,098)  (40,098)
# 23                  영업외수익 (주6,37,45)      14489     14489      12768     12768
# 24                     영업외비용 (주6,38)      14607     14607      52866     52866
# 25                  법인세비용차감전순이익 (주6)     346067    346067     230375    230375
# 26                  법인세비용 (주6,39,45)      87842     87842      61714     61714
# 27                    당기순이익(손실) (주6)     258225    258225     168661    168661
# 28                       지배기업의 소유주지분     258735    258735     162859    162859
# 29                             비지배지분      (510)     (510)       5802      5802
# 30                            기타포괄손익   (39,431)  (39,431)      47677     47677
# 31             후속적으로 당기손익으로 재분류되는 항목        NaN       NaN        NaN       NaN
# 32        기타포괄손익-공정가치측정금융자산평가손익 (주9)      18097     18097    (1,180)   (1,180)
# 33             관계기업투자자산평가손익 (주12,45)   (34,180)  (34,180)   (76,425)  (76,425)
# 34           해외사업장순투자에 대한 위험회피 (주23)       1545      1545       1572      1572
# 35                          해외사업환산손익    (9,705)   (9,705)     208109    208109
# 36          후속적으로 당기손익으로 재분류되지 않는 항목        NaN       NaN        NaN       NaN
# 37      기타포괄손익-공정가치측정지정금융자산평가손익 (주9)   (12,716)  (12,716)   (79,814)  (79,814)
# 38                관계기업투자자산평가손익 (주12)          7         7          0         0
# 39  당기손익-공정가치측정지정금융부채의 신용위험 변동 (주18)    (2,161)   (2,161)    (4,585)   (4,585)
# 40                      확정급여제도의재측정요소      (318)     (318)          0         0
# 41                           당기총포괄손익     218794    218794     216338    216338
# 42                       지배기업의 소유주지분     219364    219364     210464    210464
# 43                             비지배지분      (570)     (570)       5874      5874
# 44                        주당이익 (주40)        NaN       NaN        NaN       NaN
# 45             기본 주당이익(보통주) (단위 : 원)        441       441        269       269
# 46             희석 주당이익(보통주) (단위 : 원)        441       441        269       269
# 47             기본 주당이익(우선주) (단위 : 원)        441       441        269       269
# 48             희석 주당이익(우선주) (단위 : 원)        441       441        269       269
